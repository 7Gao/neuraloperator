# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load('FNO_pred_lwr_fourier_m2.npz')
pred = data['y_pred']
true = data['y_true']

l2_error = np.zeros(200)
for i in range(200):
    l2_error[i] = np.linalg.norm(pred[i, 0, :] - true[i, 0, :])
    l2_error[i] /= np.linalg.norm(true[i, 0, :])
print(np.mean(l2_error))

# %%
plt.plot(pred[0, 0, :], label='Predicted')
plt.plot(true[0, 0, :], label='True')
plt.show()
